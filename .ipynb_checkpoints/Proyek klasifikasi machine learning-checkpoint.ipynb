# %% [markdown]
# # Proyek Machine Learning 1: [Heart Prediction Quantum Dataset]
# - **Nama:** [Andreas Kevin]
# - **Email:** [Kevinandreas913@gmail.com]
# - **ID Dicoding:** [andreas_kevin_6396]

# %% [markdown]
# ## Menentukan Pertanyaan Bisnis

# %% [markdown]
# - Bagaimana perkembangan tingkat penyewaan pada 30 hari belakang berdasarkan total semua penyewa (registrasi dan casual)?
# - Berdasarkan penyewa casual dan registered, berapa persentase penyewa dari casual dan registered?

# %% [markdown]
# ## Import Semua Packages/Library yang Digunakan

# %%
import pandas as pd  
import matplotlib.pyplot as plt 
import sklearn.cluster as cls 
from sklearn.preprocessing import MinMaxScaler 
import numpy as np 
import seaborn as sns 
# from sklearn.neural_network import ann
import sklearn.neural_network as ann
import sklearn.metrics as met #evaluasi model
from sklearn.model_selection import GridSearchCV, train_test_split

# %% [markdown]
# ## Data Understanding

# %% [markdown]
# ### Data gathering

# %% [markdown]
# - Dataset diperoleh dari: https://www.kaggle.com/datasets/shantanugarg274/heart-prediction-dataset-quantum
# - Dataset didownload dalam format .csv file

# %%
df_heart = pd.read_csv("Heart Prediction Quantum Dataset.csv", sep=",")
display(df_heart)
# Out:
#      Age  Gender  BloodPressure  Cholesterol  HeartRate  \
# 0     68       1            105          191        107
# 1     58       0             97          249         89
# 2     44       0             93          190         82
# 3     72       1             93          183        101
# 4     37       0            145          166        103
# ..   ...     ...            ...          ...        ...
# 495   34       0            126          292        116
# 496   41       0            164          248        114
# 497   45       1            159          175         75
# 498   55       0            107          157        101
# 499   55       0            174          249         89
#
#      QuantumPatternFeature  HeartDisease
# 0                 8.362241             1
# 1                 9.249002             0
# 2                 7.942542             1
# 3                 6.495155             1
# 4                 7.653900             1
# ..                     ...           ...
# 495               9.303403             0
# 496               9.067889             0
# 497               8.718708             0
# 498               7.337650             1
# 499              10.492950             0
#
# [500 rows x 7 columns]

# %% [markdown]
# **Insight:**
# - Proses pengumpulan data berdasarkan data "Bike Sharing Dataset".
# - Dalam menjawab pertanyaan bisnis yang disampaikan, pengumpulan data akan berfokus pada data "day.csv".
# - Data dalam bentuk csv sehingga pemanggilan data dan visualisasi tabel diperlukan library pandas.

# %% [markdown]
# ### EDA (Exploratory Data Analysis)

# %%
df_heart.info()

print("jumlah data kosong: ", df_heart.isnull().sum())
print("Jumlah duplikasi: ", df_heart.duplicated().sum())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 500 entries, 0 to 499
# Data columns (total 7 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Age                    500 non-null    int64
#  1   Gender                 500 non-null    int64
#  2   BloodPressure          500 non-null    int64
#  3   Cholesterol            500 non-null    int64
#  4   HeartRate              500 non-null    int64
#  5   QuantumPatternFeature  500 non-null    float64
#  6   HeartDisease           500 non-null    int64
# dtypes: float64(1), int64(6)
# memory usage: 27.5 KB
# jumlah data kosong:  Age                      0
# Gender                   0
# BloodPressure            0
# Cholesterol              0
# HeartRate                0
# QuantumPatternFeature    0
# HeartDisease             0
# dtype: int64
# Jumlah duplikasi:  0

# %% [markdown]
# **Insight:**
# - Proses df_heart.info() pada data tersebut menampilkan jenis kolom, tipe data dan isi dari kolom tersebut.
# - Tidak ada masalah dengan jumlah data yang dimunculkan (semua data terisi dan tidak ada kosong).
# - Tidak ada duplipkasi data dari dataframe tersebut.

# %%
df_heart.describe()
# Out:
#               Age      Gender  BloodPressure  Cholesterol   HeartRate  \
# count  500.000000  500.000000     500.000000    500.00000  500.000000
# mean    54.864000    0.468000     132.874000    221.50000   88.766000
# std     14.315004    0.499475      26.418516     43.86363   17.417289
# min     30.000000    0.000000      90.000000    150.00000   60.000000
# 25%     43.000000    0.000000     111.000000    183.75000   73.000000
# 50%     55.000000    0.000000     132.000000    221.00000   89.000000
# 75%     66.250000    1.000000     155.000000    258.00000  104.000000
# max     79.000000    1.000000     179.000000    299.00000  119.000000
#
#        QuantumPatternFeature  HeartDisease
# count             500.000000    500.000000
# mean                8.317407      0.600000
# std                 0.919629      0.490389
# min                 6.164692      0.000000
# 25%                 7.675779      0.000000
# 50%                 8.323064      1.000000
# 75%                 8.935999      1.000000
# max                10.784886      1.000000

# %% [markdown]
# **Insight:**
# - Kode df_heart.describe() bertujuan untuk menunjukkan parameter statistik.
# - data parameter statistik yang dihsilkan tidak menunjukkan adanya keanehan pada data.

# %%
def outlier(nama):
    q25, q75 = np.percentile(df_heart[nama], 25), np.percentile(df_heart[nama], 75)
    iqr = q75 - q25
    cut_off = iqr * 1.5
    minimum, maximum = q25 - cut_off, q75 + cut_off
     
    outlier = [x for x in df_heart[nama] if x < minimum or x > maximum]
    return outlier

for atribut in df_heart.columns:
    print(f"Adapun outlier pada atribut {atribut} : {outlier(atribut)}")
# Out:
# Adapun outlier pada atribut Age : []
# Adapun outlier pada atribut Gender : []
# Adapun outlier pada atribut BloodPressure : []
# Adapun outlier pada atribut Cholesterol : []
# Adapun outlier pada atribut HeartRate : []
# Adapun outlier pada atribut QuantumPatternFeature : []
# Adapun outlier pada atribut HeartDisease : []

# %% [markdown]
# **Insight:**
# - Kode diatas merupakan proses pemeriksaan outlier menggunakan teknik IQR berdasarkan 25% dan 75%.
# - Terlihat tidak ada outlier pada semua atribut yang menunjukkan bahwa data sudah bersih dari outlier.

# %% [markdown]
# ### Visualization EDA (Exploratory Data Analysis)

# %%
def boxplot(name):
    plt.figure(figsize=(10, 6))
    sns.boxplot(data=df_heart[[name]])
    plt.show()

# Loop untuk menampilkan boxplot
for col in df_heart.columns:
    print(f"Boxplot untuk {col}:")
    boxplot(col)
# Out:
# Boxplot untuk Age:
# Boxplot untuk Gender:
# Boxplot untuk BloodPressure:
# Boxplot untuk Cholesterol:
# Boxplot untuk HeartRate:
# Boxplot untuk QuantumPatternFeature:
# Boxplot untuk HeartDisease:

# %% [markdown]
# **Insight:**
# - Proses diatas merupakan visualisasi boxplot yang membntu visualisasi dalam pemeriksaan outlier sebelumnya.

# %%
numeric_df = df_heart.select_dtypes(include=[np.number])

plt.figure(figsize=(10, 6))
sns.heatmap(numeric_df.corr(), annot=True, cmap="coolwarm", fmt=".2f")
plt.show()

# %%
def histogram(name):
    plt.figure(figsize=(10, 6))
    sns.histplot(df_heart[name], bins=30, kde=True)
    plt.xlabel(name)
    plt.ylabel("Frequency")
    plt.title(f"Histogram untuk {name}")
    plt.show()

for col in df_heart.select_dtypes(include=[np.number]).columns:
    print(f"Histogram untuk {col}:")
    histogram(col)
# Out:
# Histogram untuk Age:
# Histogram untuk Gender:
# Histogram untuk BloodPressure:
# Histogram untuk Cholesterol:
# Histogram untuk HeartRate:
# Histogram untuk QuantumPatternFeature:
# Histogram untuk HeartDisease:

# %% [markdown]
# ## Data Prepration

# %%
X = df_heart.drop(['HeartDisease'], axis=1)
y = df_heart['HeartDisease']

# %%
X_train_MLP, X_test_MLP, y_train_MLP, y_test_MLP = train_test_split(X, y, test_size=0.2)

# %% [markdown]
# ## Model Development

# %% [markdown]
# ! Test KNN

# %%
from sklearn.neighbors import KNeighborsClassifier

knn = KNeighborsClassifier(n_neighbors=13)
knn.fit(X_train_MLP, y_train_MLP)
# Out:
# KNeighborsClassifier(n_neighbors=13)

# %%
y_pred_MLP = knn.predict(X_test_MLP)

# %%
akurasi_MLP = met.accuracy_score(y_test_MLP, y_pred_MLP)
f1score_MLP = met.f1_score(y_test_MLP, y_pred_MLP, average='weighted')
precision_MLP = met.precision_score(y_test_MLP, y_pred_MLP, average='weighted')
recall_MLP = met.recall_score(y_test_MLP, y_pred_MLP, average='weighted')

print("Akurasi:", akurasi_MLP)
print("F1-Score:", f1score_MLP)
print("Precision:", precision_MLP)
print("Recall:", recall_MLP)

cm_MLP = met.confusion_matrix(y_test_MLP, y_pred_MLP)

# Buat visualisasi dengan heatmap
plt.figure(figsize=(6,5))
sns.heatmap(cm_MLP, annot=True, fmt='d', cmap='Blues')

plt.xlabel("Predicted Label")
plt.ylabel("True Label")
plt.title("Confusion Matrix")
plt.show()
# Out:
# Akurasi: 0.75
# F1-Score: 0.7493928835392251
# Precision: 0.7489388794567062
# Recall: 0.75

# %% [markdown]
# ### MLP (Multi Layer Perceptron)

# %%
mlp = MLPClassifier(max_iter=1000, random_state=42, solver='adam')

# %%
# Buat grid search
param_grid = {
    'hidden_layer_sizes': [(50,), (100,), (50,50), (100,100), (50,50,50), (100,100,100)],
    'activation': ['relu', 'tanh', 'logistic'],
    'alpha': [0.0001, 0.001, 0.01],
    'learning_rate': ['constant', 'adaptive']
}

# %%
grid_search = GridSearchCV(mlp, param_grid, cv=5, n_jobs=-1, verbose=2)
grid_search.fit(X_train_MLP, y_train_MLP)
print(f"Best Parameter: {grid_search.best_params_}")
# Out:
# Fitting 5 folds for each of 108 candidates, totalling 540 fits
# Best Parameters: {'activation': 'logistic', 'alpha': 0.01, 'hidden_layer_sizes': (50, 50), 'learning_rate': 'constant'}

# %%
# Best model evaluation
best_model = grid_search.best_estimator_
y_pred_MLP = best_model.predict(X_test_MLP)

# %% [markdown]
# ## Evaluation

# %% [markdown]
# ### Evaluation MLP Model

# %%
akurasi_MLP = met.accuracy_score(y_test_MLP, y_pred_MLP)
f1score_MLP = met.f1_score(y_test_MLP, y_pred_MLP, average='weighted')
precision_MLP = met.precision_score(y_test_MLP, y_pred_MLP, average='weighted')
recall_MLP = met.recall_score(y_test_MLP, y_pred_MLP, average='weighted')

print("Akurasi:", akurasi_MLP)
print("F1-Score:", f1score_MLP)
print("Precision:", precision_MLP)
print("Recall:", recall_MLP)

cm_MLP = met.confusion_matrix(y_test_MLP, y_pred_MLP)

# Buat visualisasi dengan heatmap
plt.figure(figsize=(6,5))
sns.heatmap(cm_MLP, annot=True, fmt='d', cmap='Blues')

plt.xlabel("Predicted Label")
plt.ylabel("True Label")
plt.title("Confusion Matrix")
plt.show()
# Out:
# Akurasi: 0.79
# F1-Score: 0.7861115475255303
# Precision: 0.786517064048621
# Recall: 0.79
